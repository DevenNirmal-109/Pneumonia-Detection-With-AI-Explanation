# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Project\AI That Explains Medical Images Like a Doctor\Dataset\stage_2_train_labels.csv")
df2 = pd.read_csv(r"D:\Project\AI That Explains Medical Images Like a Doctor\Dataset\stage_2_detailed_class_info.csv")

# %%
df.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
df2.head()
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#              class
# 0  No lung opacity
# 1  No lung opacity
# 2  No lung opacity
# 3           Normal
# 4     Lung Opacity

# %%
df2[df2['class']=='No Lung Opacity / Not Normal'] = 'No lung opacity'

# %%
df['class'] = df2['class']

# %%
df.head()
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#              class
# 0  No lung opacity
# 1  No lung opacity
# 2  No lung opacity
# 3           Normal
# 4     Lung Opacity

# %%
df.to_csv(r"D:\Project\AI That Explains Medical Images Like a Doctor\Another way\Dataset\stage_2_detailed_class_info.csv", index=False)

# %%
df = pd.read_csv(r"D:\Project\AI That Explains Medical Images Like a Doctor\Another way\Dataset\stage_2_train_labels.csv")

# %%
df.head()
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#              class
# 0  No lung opacity
# 1  No lung opacity
# 2  No lung opacity
# 3           Normal
# 4     Lung Opacity
